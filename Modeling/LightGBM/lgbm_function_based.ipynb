# %%
import lightgbm as lgb # Changed from xgboost
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (confusion_matrix, classification_report,
                             f1_score, accuracy_score, recall_score)
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# --- Global Configuration ---

# Columns to drop before training (likely common across all datasets)
# Note: Added 'duration' drop as requested in your LightGBM code snippet
DROP_COLS = ['start_time', 'end_time', 'cow', 'duration']

# Base LightGBM Hyperparameters (num_class will be set dynamically)
BASE_LGBM_CONFIG = {
    'objective': 'multiclass',
    'metric': 'multi_logloss',
    'random_state': 42,
    'learning_rate': 0.1,
    'max_depth': 7,
    'n_estimators': 200,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'num_leaves': 63 # Default setting for LightGBM
}

def load_data(path: str, dataset_name: str):
    """Safely loads a CSV file."""
    try:
        # Use r to handle paths with backslashes
        df = pd.read_csv(path) 
        print(f"   -> Loaded {dataset_name} data from: {path} ({len(df)} rows)")
        return df
    except FileNotFoundError:
        print(f"🛑 Error: {dataset_name} file not found at path: {path}")
        return None
    except Exception as e:
        print(f"🛑 Error loading {dataset_name} dataset from {path}: {e}")
        return None

def evaluate_model_and_plot(model, X, y_true, le: LabelEncoder, analysis_name: str, split_name: str):
    """
    Evaluates the trained model on a given dataset split, prints metrics,
    and visualizes the confusion matrix.
    """
    print(f"\n--- Evaluation for {analysis_name} ({split_name}) ---")

    # 1. Prediction
    try:
        y_pred = model.predict(X)
    except Exception as e:
        print(f"Error during prediction on {split_name} for {analysis_name}: {e}")
        return

    # 2. Global metrics
    # Note: Handles case where y_true might only contain one class for smaller splits
    if len(np.unique(y_true)) > 1:
        f1 = f1_score(y_true, y_pred, average='macro', zero_division=0)
        recall = recall_score(y_true, y_pred, average='macro', zero_division=0)
    else:
        # If only one class is present, use weighted average for robustness
        f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
        recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
        
    accuracy = accuracy_score(y_true, y_pred)

    print("🎯 Global Metrics")
    # Indicate that macro/weighted is used for clarity
    print(f"F1 Score (Macro/Weighted*): {f1:.4f}") 
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Recall (Macro/Weighted*): {recall:.4f}\n")

    # 3. Classification report
    print("📋 Classification Report (Per Class):")
    # Setting zero_division to 0 ensures clean output even if a class is entirely missing from a split
    # Explicitly pass all encoded labels (0, 1, 2, ... N-1) to ensure the table size matches target_names
    print(classification_report(
        y_true, 
        y_pred, 
        target_names=le.classes_, 
        labels=np.arange(len(le.classes_)), 
        zero_division=0
    ))

    # 4. Confusion Matrix Calculation
    # Ensure cm uses the full set of class indices (0 to N-1) for consistency
    cm = confusion_matrix(y_true, y_pred, labels=np.arange(len(le.classes_)))
    
    # Calculate row sums for normalization
    row_sums = cm.sum(axis=1)
    
    # Normalize by row sum (True label distribution)
    # np.divide ensures safe division by zero, resulting in 0 where division is impossible
    cm_normalized = np.divide(cm.astype('float'), row_sums[:, np.newaxis], out=np.zeros_like(cm, dtype=float), where=row_sums[:, np.newaxis]!=0)

    # 5. Plotting
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm_normalized, annot=False, cmap='Blues', cbar=True)

    # Add counts and normalized percentages to the heatmap
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            # Display count and percentage in the center of the cell
            plt.text(j+0.5, i+0.5, f"{cm[i, j]}\n({cm_normalized[i,j]*100:.2f}%)",
                     ha='center', va='center',
                     fontsize=10,
                     color='white' if cm_normalized[i,j] > 0.5 else 'black')

    # Tick labels
    plt.xticks(np.arange(len(le.classes_)) + 0.5, le.classes_, rotation=45, ha='right')
    plt.yticks(np.arange(len(le.classes_)) + 0.5, le.classes_, rotation=0)
    plt.title(f'LightGBM Confusion Matrix for {analysis_name} ({split_name})', fontsize=14, weight='bold')
    plt.xlabel('Predicted Label', fontsize=12)
    plt.ylabel('True Label', fontsize=12)
    plt.tight_layout()
    plt.show()


def run_lightgbm_pipeline(analysis_name: str, main_data_path: str, unseen_path: str, drop_cols: list, target_cols: list, base_lgbm_config: dict, test_size: float = 0.2):
    """
    Runs the full LightGBM training and evaluation pipeline.
    It splits the data from `main_data_path` into Training and Testing sets,
    and uses `unseen_path` for final evaluation.
    
    The number of classes for LightGBM is determined dynamically by the length of target_cols.
    """
    print(f"\n=======================================================")
    print(f"🚀 Starting LightGBM Pipeline for: {analysis_name}")
    print(f"=======================================================")

    # 1. Load the two primary datasets
    df_main = load_data(main_data_path, f"{analysis_name} Main (Train/Test)")
    df_unseen = load_data(unseen_path, f"{analysis_name} Unseen")

    if df_main is None or df_unseen is None:
        print(f"🛑 Pipeline aborted for {analysis_name} due to missing data.")
        return

    # 1.5 Split the main data into Training and Testing sets
    print(f"   -> Splitting main data (Train/Test) with test_size={test_size}")
    df_train, df_test = train_test_split(df_main, test_size=test_size, random_state=42)
    
    # 2. Drop unnecessary columns from all splits
    # Note: using errors='ignore' in the function call already
    df_train.drop(columns=drop_cols, errors='ignore', inplace=True)
    df_test.drop(columns=drop_cols, errors='ignore', inplace=True)
    df_unseen.drop(columns=drop_cols, errors='ignore', inplace=True)
    
    # 3. Check if target columns exist after dropping
    missing_target_cols = [col for col in target_cols if col not in df_train.columns]
    if missing_target_cols:
        print(f"🛑 Error: Target columns {missing_target_cols} not found in the primary (Training) dataset's feature space.")
        return

    # 4. Multi-class target creation
    # The max value across the target columns determines the class
    try:
        df_train['target'] = df_train[target_cols].idxmax(axis=1)
        df_test['target'] = df_test[target_cols].idxmax(axis=1)
        df_unseen['target'] = df_unseen[target_cols].idxmax(axis=1)
    except KeyError as e:
        print(f"🛑 Error: One of the specified target columns is missing in a split for {analysis_name}: {e}")
        return

    # 5. Label encoding: Define classes explicitly and then transform
    le = LabelEncoder()
    # FIT the encoder using the specific target column names (the strings),
    # ensuring the internal class list is exactly the length of target_cols.
    le.fit(target_cols) 
    
    # Transform data using the fitted encoder
    try:
        y_train = le.transform(df_train['target'])
        y_test = le.transform(df_test['target'])
        y_unseen = le.transform(df_unseen['target'])
    except ValueError as e:
        # Catches cases where data contains classes not in 'target_cols'
        print(f"🛑 Error: Data contains classes not defined in 'target_cols'. Details: {e}")
        return
        
    print(f"   -> Classes found and encoded (based on target_cols): {le.classes_}")

    # 6. Split features and labels
    X_train = df_train.drop(columns=target_cols + ['target'])
    X_test = df_test.drop(columns=target_cols + ['target'])
    X_unseen = df_unseen.drop(columns=target_cols + ['target'])
    
    # Final check to ensure feature sets are consistent
    if not X_train.columns.equals(X_test.columns) or not X_train.columns.equals(X_unseen.columns):
        print(f"⚠️ Warning: Feature columns are inconsistent between splits for {analysis_name}. Attempting column alignment.")
        # Attempt to align columns to prevent prediction errors, filling missing features with 0
        common_cols = X_train.columns.tolist()
        X_test = X_test.reindex(columns=common_cols, fill_value=0)
        X_unseen = X_unseen.reindex(columns=common_cols, fill_value=0)
    
    print(f"   -> Training samples: {len(X_train)}, Testing samples: {len(X_test)}, Unseen samples: {len(X_unseen)}")

    # 7. LightGBM model initialization and training
    # Prepare parameters, setting num_class dynamically based on the current dataset's labels
    lgbm_params = base_lgbm_config.copy()
    lgbm_params['num_class'] = len(target_cols)
    
    model = lgb.LGBMClassifier(**lgbm_params)
    model.fit(X_train, y_train)
    print("   -> Model trained successfully.")

    # 8. Evaluation on Test Data
    evaluate_model_and_plot(model, X_test, y_test, le, analysis_name, "Test Set (20% Split)")

    # 9. Evaluation on Unseen Data
    evaluate_model_and_plot(model, X_unseen, y_unseen, le, analysis_name, "Unseen Set (Separate File)")
    
    print(f"\n✅ Pipeline finished for: {analysis_name}")
    print("-------------------------------------------------------")
    
    return model

# --- Main Execution Loop ---

# Define the paths and LABELS for your four datasets.
# IMPORTANT: You MUST update the 'main_data_path', 'unseen_path', 
# and the 'target_cols' for each dataset configuration to match your files.
datasets_to_run = [
 {
        'name': 'Dataset 1 Analysis ',
        'target_cols': ['oestrus', 'mastitis', 'calving', 'lameness', 'other_disease', 'ok'],
        'main_data_path': r"C:/Users/lamia/Downloads/dataset1_balanced_trainval.csv",
        'unseen_path': r"C:/Users/lamia/Downloads/dataset1_balanced_holdout.csv",
        'test_size': 0.2
    },
    {
        'name': 'Dataset 2 Analysis',

        'target_cols': ['oestrus', 'mastitis', 'lameness', 'other_disease', 'ok'],
        'main_data_path': r"C:/Users/lamia/Downloads/dataset2_balanced_trainval.csv",
        'unseen_path': r"C:/Users/lamia/Downloads/dataset2_balanced_holdout.csv",
        'test_size': 0.2
    },
    {
        'name': 'Dataset 3 Analysis',

        'target_cols': ['oestrus', 'ok'],
        'main_data_path': r"C:/Users/lamia/Downloads/dataset3_balanced_trainval.csv",
        'unseen_path': r"C:/Users/lamia/Downloads/dataset3_balanced_holdout.csv",
        'test_size': 0.2
    },

    {
        'name': 'Dataset 4 Analysis',

        'target_cols': ['oestrus', 'calving','mastitis', 'lameness', 'other_disease', 'ok'],
        'main_data_path': r"C:/Users/lamia/Downloads/dataset4_balanced_trainval.csv",
        'unseen_path': r"C:/Users/lamia/Downloads/dataset4_balanced_holdout.csv",
        'test_size': 0.2
    }
    
]

# Run the pipeline for all defined datasets
trained_models = {}
for config in datasets_to_run:
    # Use .get() for test_size to allow default value (0.2) if not specified
    model = run_lightgbm_pipeline(
        analysis_name=config['name'],
        main_data_path=config['main_data_path'],
        unseen_path=config['unseen_path'],
        drop_cols=DROP_COLS,
        target_cols=config['target_cols'],
        base_lgbm_config=BASE_LGBM_CONFIG,
        test_size=config.get('test_size', 0.2)
    )
    if model:
        # Store the trained model if successful
        trained_models[config['name']] = model

print("\n\nAll LightGBM analysis pipelines completed.")
print(f"Successfully trained and evaluated models for: {list(trained_models.keys())}")
# Out:
# c:\Users\lamia\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# =======================================================
# 🚀 Starting LightGBM Pipeline for: Dataset 1 Analysis
# =======================================================
#    -> Loaded Dataset 1 Analysis  Main (Train/Test) data from: C:/Users/lamia/Downloads/dataset1_balanced_trainval.csv (535532 rows)
#    -> Loaded Dataset 1 Analysis  Unseen data from: C:/Users/lamia/Downloads/dataset1_balanced_holdout.csv (59504 rows)
#    -> Splitting main data (Train/Test) with test_size=0.2
#    -> Classes found and encoded (based on target_cols): ['calving' 'lameness' 'mastitis' 'oestrus' 'ok' 'other_disease']
#    -> Training samples: 428425, Testing samples: 107107, Unseen samples: 59504
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.017437 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5610
# [LightGBM] [Info] Number of data points in the train set: 428425, number of used features: 22
# [LightGBM] [Info] Start training from score -1.780856
# [LightGBM] [Info] Start training from score -1.779637
# [LightGBM] [Info] Start training from score -1.779790
# [LightGBM] [Info] Start training from score -1.781660
# [LightGBM] [Info] Start training from score -1.849500
# [LightGBM] [Info] Start training from score -1.781064
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#    -> Model trained successfully.
#
# --- Evaluation for Dataset 1 Analysis  (Test Set (20% Split)) ---
# 🎯 Global Metrics
# F1 Score (Macro/Weighted*): 0.9955
# Accuracy: 0.9956
# Recall (Macro/Weighted*): 0.9955
#
# 📋 Classification Report (Per Class):
#                precision    recall  f1-score   support
#
#       calving       1.00      1.00      1.00     18034
#      lameness       1.00      1.00      1.00     17946
#      mastitis       1.00      1.00      1.00     17956
#       oestrus       0.99      0.99      0.99     18072
#            ok       0.99      0.98      0.99     17051
# other_disease       1.00      1.00      1.00     18048
#
#      accuracy                           1.00    107107
#     macro avg       1.00      1.00      1.00    107107
#  weighted avg       1.00      1.00      1.00    107107
# --- Evaluation for Dataset 1 Analysis  (Unseen Set (Separate File)) ---
# 🎯 Global Metrics
# F1 Score (Macro/Weighted*): 0.9955
# Accuracy: 0.9956
# Recall (Macro/Weighted*): 0.9955
#
# 📋 Classification Report (Per Class):
#                precision    recall  f1-score   support
#
#       calving       1.00      1.00      1.00     10025
#      lameness       1.00      1.00      1.00     10025
#      mastitis       1.00      1.00      1.00     10024
#       oestrus       0.99      0.99      0.99     10022
#            ok       0.99      0.98      0.99      9383
# other_disease       1.00      1.00      1.00     10025
#
#      accuracy                           1.00     59504
#     macro avg       1.00      1.00      1.00     59504
#  weighted avg       1.00      1.00      1.00     59504
# ✅ Pipeline finished for: Dataset 1 Analysis
# -------------------------------------------------------
#
# =======================================================
# 🚀 Starting LightGBM Pipeline for: Dataset 2 Analysis
# =======================================================
#    -> Loaded Dataset 2 Analysis Main (Train/Test) data from: C:/Users/lamia/Downloads/dataset2_balanced_trainval.csv (131239 rows)
#    -> Loaded Dataset 2 Analysis Unseen data from: C:/Users/lamia/Downloads/dataset2_balanced_holdout.csv (14583 rows)
#    -> Splitting main data (Train/Test) with test_size=0.2
#    -> Classes found and encoded (based on target_cols): ['lameness' 'mastitis' 'oestrus' 'ok' 'other_disease']
#    -> Training samples: 104991, Testing samples: 26248, Unseen samples: 14583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003665 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5610
# [LightGBM] [Info] Number of data points in the train set: 104991, number of used features: 22
# [LightGBM] [Info] Start training from score -1.373716
# [LightGBM] [Info] Start training from score -1.381610
# [LightGBM] [Info] Start training from score -1.380776
# [LightGBM] [Info] Start training from score -1.409448
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#    -> Model trained successfully.
#
# --- Evaluation for Dataset 2 Analysis (Test Set (20% Split)) ---
# 🎯 Global Metrics
# F1 Score (Macro/Weighted*): 0.9998
# Accuracy: 0.9998
# Recall (Macro/Weighted*): 0.9998
#
# 📋 Classification Report (Per Class):
#                precision    recall  f1-score   support
#
#      lameness       1.00      1.00      1.00      6477
#      mastitis       1.00      1.00      1.00      6686
#       oestrus       1.00      1.00      1.00      6664
#            ok       1.00      1.00      1.00      6421
# other_disease       0.00      0.00      0.00         0
#
#      accuracy                           1.00     26248
#     macro avg       0.80      0.80      0.80     26248
#  weighted avg       1.00      1.00      1.00     26248
# --- Evaluation for Dataset 2 Analysis (Unseen Set (Separate File)) ---
# 🎯 Global Metrics
# F1 Score (Macro/Weighted*): 0.9995
# Accuracy: 0.9995
# Recall (Macro/Weighted*): 0.9995
#
# 📋 Classification Report (Per Class):
#                precision    recall  f1-score   support
#
#      lameness       1.00      1.00      1.00      3673
#      mastitis       1.00      1.00      1.00      3673
#       oestrus       1.00      1.00      1.00      3673
#            ok       1.00      1.00      1.00      3564
# other_disease       0.00      0.00      0.00         0
#
#      accuracy                           1.00     14583
#     macro avg       0.80      0.80      0.80     14583
#  weighted avg       1.00      1.00      1.00     14583
# ✅ Pipeline finished for: Dataset 2 Analysis
# -------------------------------------------------------
#
# =======================================================
# 🚀 Starting LightGBM Pipeline for: Dataset 3 Analysis
# =======================================================
#    -> Loaded Dataset 3 Analysis Main (Train/Test) data from: C:/Users/lamia/Downloads/dataset3_balanced_trainval.csv (40181 rows)
#    -> Loaded Dataset 3 Analysis Unseen data from: C:/Users/lamia/Downloads/dataset3_balanced_holdout.csv (4465 rows)
#    -> Splitting main data (Train/Test) with test_size=0.2
#    -> Classes found and encoded (based on target_cols): ['oestrus' 'ok']
#    -> Training samples: 32144, Testing samples: 8037, Unseen samples: 4465
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001434 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5596
# [LightGBM] [Info] Number of data points in the train set: 32144, number of used features: 22
# [LightGBM] [Info] Start training from score -0.638720
# [LightGBM] [Info] Start training from score -0.750708
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#    -> Model trained successfully.
#
# --- Evaluation for Dataset 3 Analysis (Test Set (20% Split)) ---
# 🎯 Global Metrics
# F1 Score (Macro/Weighted*): 0.9845
# Accuracy: 0.9846
# Recall (Macro/Weighted*): 0.9846
#
# 📋 Classification Report (Per Class):
#               precision    recall  f1-score   support
#
#      oestrus       0.99      0.98      0.99      4289
#           ok       0.98      0.99      0.98      3748
#
#     accuracy                           0.98      8037
#    macro avg       0.98      0.98      0.98      8037
# weighted avg       0.98      0.98      0.98      8037
# --- Evaluation for Dataset 3 Analysis (Unseen Set (Separate File)) ---
# 🎯 Global Metrics
# F1 Score (Macro/Weighted*): 0.9861
# Accuracy: 0.9861
# Recall (Macro/Weighted*): 0.9860
#
# 📋 Classification Report (Per Class):
#               precision    recall  f1-score   support
#
#      oestrus       0.99      0.99      0.99      2363
#           ok       0.99      0.98      0.99      2102
#
#     accuracy                           0.99      4465
#    macro avg       0.99      0.99      0.99      4465
# weighted avg       0.99      0.99      0.99      4465
# ✅ Pipeline finished for: Dataset 3 Analysis
# -------------------------------------------------------
#
# =======================================================
# 🚀 Starting LightGBM Pipeline for: Dataset 4 Analysis
# =======================================================
#    -> Loaded Dataset 4 Analysis Main (Train/Test) data from: C:/Users/lamia/Downloads/dataset4_balanced_trainval.csv (943294 rows)
#    -> Loaded Dataset 4 Analysis Unseen data from: C:/Users/lamia/Downloads/dataset4_balanced_holdout.csv (104811 rows)
#    -> Splitting main data (Train/Test) with test_size=0.2
#    -> Classes found and encoded (based on target_cols): ['calving' 'lameness' 'mastitis' 'oestrus' 'ok' 'other_disease']
#    -> Training samples: 754635, Testing samples: 188659, Unseen samples: 104811
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024828 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5610
# [LightGBM] [Info] Number of data points in the train set: 754635, number of used features: 22
# [LightGBM] [Info] Start training from score -1.786292
# [LightGBM] [Info] Start training from score -1.786704
# [LightGBM] [Info] Start training from score -1.786174
# [LightGBM] [Info] Start training from score -1.786427
# [LightGBM] [Info] Start training from score -1.819904
# [LightGBM] [Info] Start training from score -1.785526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#    -> Model trained successfully.
#
# --- Evaluation for Dataset 4 Analysis (Test Set (20% Split)) ---
# 🎯 Global Metrics
# F1 Score (Macro/Weighted*): 0.9995
# Accuracy: 0.9995
# Recall (Macro/Weighted*): 0.9995
#
# 📋 Classification Report (Per Class):
#                precision    recall  f1-score   support
#
#       calving       1.00      1.00      1.00     31687
#      lameness       1.00      1.00      1.00     31739
#      mastitis       1.00      1.00      1.00     31671
#       oestrus       1.00      1.00      1.00     31704
#            ok       1.00      1.00      1.00     30268
# other_disease       1.00      1.00      1.00     31590
#
#      accuracy                           1.00    188659
#     macro avg       1.00      1.00      1.00    188659
#  weighted avg       1.00      1.00      1.00    188659
# --- Evaluation for Dataset 4 Analysis (Unseen Set (Separate File)) ---
# 🎯 Global Metrics
# F1 Score (Macro/Weighted*): 0.9994
# Accuracy: 0.9994
# Recall (Macro/Weighted*): 0.9994
#
# 📋 Classification Report (Per Class):
#                precision    recall  f1-score   support
#
#       calving       1.00      1.00      1.00     17572
#      lameness       1.00      1.00      1.00     17572
#      mastitis       1.00      1.00      1.00     17573
#       oestrus       1.00      1.00      1.00     17572
#            ok       1.00      1.00      1.00     16950
# other_disease       1.00      1.00      1.00     17572
#
#      accuracy                           1.00    104811
#     macro avg       1.00      1.00      1.00    104811
#  weighted avg       1.00      1.00      1.00    104811
# ✅ Pipeline finished for: Dataset 4 Analysis
# -------------------------------------------------------
#
#
# All LightGBM analysis pipelines completed.
# Successfully trained and evaluated models for: ['Dataset 1 Analysis ', 'Dataset 2 Analysis', 'Dataset 3 Analysis', 'Dataset 4 Analysis']
